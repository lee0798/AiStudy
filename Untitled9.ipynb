# %%
#data load
import seaborn as sns
data = sns.load_dataset('penguins') # (344 row * 7 col)

# %%
sns.lineplot(data = data, x = 'body_mass_g', y = 'flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.lineplot(data = data, x = 'body_mass_g', y = 'flipper_length_mm', errorbar = None)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
#pointplot
sns.pointplot(data = data, x = 'sex', y = 'bill_length_mm')
# Out:
# <Axes: xlabel='sex', ylabel='bill_length_mm'>

# %%
# scatter plot
sns.scatterplot(data = data, x ='flipper_length_mm', y = 'body_mass_g', hue = 'sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.pairplot(data= data)

# %%
sns.pairplot(data= data, hue = 'species')

# %%
corr = data.corr()
corr
# Out:
# /var/folders/2x/4rsz6mvn7xg6_npzd8bq79dh0000gn/T/ipykernel_1630/2601176157.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(data = corr, square= True, cmap = 'Blues')
# Out:
# <Axes: >

# %%
sns.heatmap(data = corr, square= True, cmap = 'Blues', annot=True)
# Out:
# <Axes: >
